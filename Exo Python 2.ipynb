# %%
def donuts(count):
    # +++your code here+++
    if count <10:
        print ('Number of donuts: ', count)
    else:
        print ('Number of donuts: many')

# %%
def both_ends(s):
    # +++your code here+++
    if len(s)<3:
        result=""
    else:
        result=s[:2]+s[len(s)-2:]
    return result

# %%
def fix_start(s):
    # +++your code here+++
    base=s[1:]
    result=s[0]+base.replace(s[0],'*')
    return result

# %%
def mix_up(a, b):
    # +++your code here+++
    result=b[:2]+a[2:] +' ' +a[:2]+b[2:]
    return result

# %%
def main():
    # Each line calls donuts, compares its result to the expected for that call.
    donuts(4)
    donuts(9)
    donuts(10)
    donuts(99)


    print(both_ends('spring'))
    print(both_ends('Hello'))
    print(both_ends('a'))
    print(both_ends('xyz'))


    print(fix_start('babble'))
    print(fix_start('aardvark'))
    print(fix_start('google'))
    print(fix_start('donut'))


    print(mix_up('mix', 'pod'))
    print(mix_up('dog', 'dinner'))
    print(mix_up('gnash', 'sport'))
    print(mix_up('pezzy', 'firm'))

# %%
main()
# Out:
# Number of donuts:  4
# None
# Number of donuts:  9
# None
# Number of donuts: many
# None
# Number of donuts: many
# None
# spng
# Helo
#
# xyyz
# ba**le
# a*rdv*rk
# goo*le
# donut
# pox mid
# dig donner
# spash gnort
# fizzy perm

# %%
def verbing(s):
    # +++your code here+++
    if len(s)>2:
        if s[len(s)-3:]=='ing':
            s=s +'ly'
        else:
            s=s +'ing'
    return s

# %%
def front_back(a, b):
    # +++your code here+++
    if len(a)%2==0:
        indice1=int(len(a)/2)
    else:
        indice1=int((len(a)+1)/2)
        
    if len(b)%2==0:
        indice2=int(len(b)/2)
    else:
        indice2=int((len(b)+1)/2)
    
    a_front=a[:indice1]
    a_back=a[indice1:]
    
    b_front=b[:indice2]
    b_back=b[indice2:]   
        
    
    return a_front + b_front + a_back + b_back

# %%
def not_bad(s):
    # +++your code here+++
    if 'not' in s:
        if 'bad' in s:
            if s.find('not')<s.find('bad'):
                result=s[:s.find('not')]+'good'
            else:
                result=s
        else:
            result=s
    else:
        result=s
            
    return result

# %%
def main():
    print(verbing('hail'))
    print(verbing('swiming'))
    print(verbing('do'))
    

    print(not_bad('This movie is not so bad'))
    print(not_bad('This dinner is not that bad!'))
    print(not_bad('This tea is not hot'))
    print(not_bad("It's bad yet not"))

    
    print(front_back('abcd', 'xy'))
    print(front_back('abcde', 'xyz'))
    print(front_back('Kitten', 'Donut'))

# %%
main()
# Out:
# hailing
# swimingly
# do
# This movie is good
# This dinner is good
# This tea is not hot
# It's bad yet not
# abxcdy
# abcxydez
# KitDontenut
